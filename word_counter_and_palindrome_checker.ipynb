# %%
#Count Words in a String
"""
lambda can do only one operation by taking infinite values.
The operation to perform in this lambda is to print the lenghth of the list generated by .split() methods after string which create a value for each space in the string
"""

x = lambda string:print(len(string.split()))

#Check if Palindrome 
"""
if string read in reverse = reverse:
    print the given word is pandrome
"""

def pal(string):
    if string.lower()[::-1]==string.lower():
        print(f"{string} is palindrome")
