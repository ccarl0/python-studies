# %%
import random #we have to shuffle our deck

suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs') #tuple of suits (this list must be immutable)
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace') #tuple of card type (this list must be immutable)
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Jack':0.5,'Queen':0.5, 'King':0.5} #dictionary a rank = the value

playing=True #for while loops

class Card:
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
    def __str__(self):
        return self.rank + ' of ' + self.suit
    
class Deck:
    def __init__(self):
        self.deck = []  # start with an empty list
        for suit in suits:
            for rank in ranks:
                self.deck.append(Card(suit,rank))  # build Card objects and add them to the list
    def __str__(self):
        deck_comp = ''  # start with an empty string
        for card in self.deck:
            deck_comp += '\n '+card.__str__() # add each Card object's print string
        return 'The deck has:' + deck_comp
    def shuffle(self):
        random.shuffle(self.deck)
    def deal(self):
        single_card = self.deck.pop()
        return single_card
    
class Hand:
    def __init__(self):
        self.cards = []  # start with an empty list as we did in the Deck class
        self.value = 0   # start with zero value
        self.aces = 0    # add an attribute to keep track of aces
    
    def add_card(self,card):
        self.cards.append(card)
        self.value += values[card.rank]
    def adjust_for_ace(self):
        while self.value > 21 and self.aces:
            self.value -= 10
            self.aces -= 1
    
class Chips:
    def __init__(self):
        self.total = 100  #initial budget
        self.bet = 0
    def win_bet(self): #this will run in case of win
        sel.total += self.bet
    def lose_bet(self):
        self.totale-=self.bet
        

def take_bet(chips):
    while True:
        try:
            chips.bet = int(input('How many chips would you like to bet? '))
        except ValueError:
            print('Sorry, a bet must be an integer!')
        else:
            if chips.bet > chips.total:
                print("Sorry, your bet can't exceed",chips.total)
            else:
                break
                
def hit(deck,hand):
    hand.add_card(deck.deal)
    hand.adjust_for_ace()
    
def hit_or_stand(hand,deck):
    global playing #we have to change the first var value so we have to make globally changes
    while True: #we wuill reeask in case of errors
        x=input("Stand or hit? ")
        if x[0].lower() == "h":
            hit(deck,hand) #the previous func
        elif x[0].lower() == "s":
            print("cpu turn")
            playing = False #we globally change playing boolean
        else:
            print("error")
            continue #restart the while loop
        break #stops the loops
        

def show_some(player,dealer): #when we are playing one dealer's card is covered
    print("\nDealer's Hand:")
    print(" <card hidden>")
    print('',dealer.cards[1])  #second card gets showned
    print("\nPlayer's Hand:", *player.cards, sep='\n ')
    
def show_all(player,dealer): #at the end of the game all the cards get turned
    print("\nDealer's Hand:", *dealer.cards, sep='\n ')
    print("Dealer's Hand: ",dealer.value)
    print("\nPlayer's Hand:", *player.cards, sep='\n ')
    print("Player's Hand: ",player.value)
    
#all the possible final screnarios

def player_busts(player,dealer,chips):
    chips.lose_bet() #goes into chips class, finds the lose_bet meth and runs it (from the budget it substracts the bet)
    print("Player busts")

def player_wind():
    chips.win_bet() #goes into chips class, finds the win_bet meth and runs it (from the budget it sums the bet)
    print("Player wins")

def dealer_wins(player,dealer,chips):
    chips.lose_bet() #goes into chips class, finds the lose_bet meth and runs it (from the budget it substracts the bet) 
    print("Dealer wins")

def push(player,dealer,chips):
    print("Tie!") #no methods gets executed 
"""
Now we build the program
"""


print("Welcome to black jack") #this is useless
    
deck = Deck() #in deck class there is only __init__ methods that gets ran and creates an ordinated deck
deck.shuffle() #with our oridinated deck we have to shuffle it
    
player_hand = Hand() #what gets ran is only __init__ which creats self.card as an empty list
#the player starts with two cards
player_hand.add_card(deck.deal()) 
player_hand.add_card(deck.deal())

#the dealer starts with two cards
dealer_hand = Hand()
dealer_hand.add_card(deck.deal())
dealer_hand.add_card(deck.deal())

#creating the budget
player_chips = Chips() 

#taking player input
take_bet(player_chips)

#during the game the cards are shown (2 for the player, one for the dealer)
show_some(player_hand,dealer_hand)

#this block works only while we are playing
while playing:
    hit_or_stand(deck,player_hand) #runs the function that asks if stay or hit
    show_some(player_hand,dealer_hand) #during the game some card gets showned
    if player_hand.value > 21: 
            player_busts(player_hand,dealer_hand,player_chips) #p_busts func
            break #the game finishes
    if player_hand.value <= 21: #if pl. still in game
        
        while dealer_hand.value < 17: #the dealer hits only if its result is lower than 17
            hit(deck,dealer_hand)
        show_all(player_hand,dealer_hand) #at the end of the game all the cards get showned
    
        if dealer_hand.value > 21: #the dealer may hit a high card so it busts
            dealer_busts(player_hand,dealer_hand,player_chips)

        elif dealer_hand.value > player_hand.value: #if dealer is higher than pl. but under 21 he wins
            dealer_wins(player_hand,dealer_hand,player_chips)

        elif dealer_hand.value < player_hand.value: #same case above reversed
            player_wins(player_hand,dealer_hand,player_chips)

        else: #tie!
            push(player_hand,dealer_hand)
            
    print("\nPlayer's winnings stand at",player_chips.total) #prints the result
    
    new_game = input("Would you like to play another hand? Enter 'y' or 'n' ") #new game?
    
    if new_game[0].lower()=='y':
        playing=True #now we are playing
        continue #and restart the while that we wrote at the top of all
    
    else:
        print("Thanks for playing!")
        break #other

# %%
"""
I used the old version of blackjack and readjusted it for this game. There are things to improve
"""

import random

suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Jack':0.5, 'Queen':0.5, 'King':0.5, 'Ace':1}

playing = True 

class Card:
    
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        
    def __str__(self):
        return self.rank + ' of ' + self.suit
    

class Deck:
    
    def __init__(self):
        self.deck = []  
        for suit in suits:
            for rank in ranks:
                self.deck.append(Card(suit,rank))
                
    def __str__(self):
        deck_comp = ''  
        for card in self.deck:
            deck_comp += '\n '+card.__str__()
        return 'The deck has:' + deck_comp
                
    def shuffle(self):
        random.shuffle(self.deck)
        
    def deal(self):
        single_card = self.deck.pop()
        return single_card
    

class Hand:
    
    def __init__(self):
        self.cards = []  
        self.value = 0   
        self.aces = 0    
    
    def add_card(self,card):
        self.cards.append(card)
        self.value += values[card.rank]
        if card.rank == 'Ace':
            self.aces += 1  
            

class Chips:
    
    def __init__(self):
        self.total = 5
        self.bet = 0
        
    def win_bet(self):
        self.total += self.bet
    
    def lose_bet(self):
        self.total -= self.bet
        


def take_bet(chips):

    while True:
        try:
            chips.bet = int(input('How many chips would you like to bet? '))
        except ValueError:
            print('Sorry, a bet must be an integer!')
        else:
            if chips.bet > chips.total:
                print("Sorry, your bet can't exceed",chips.total)
            else:
                break

def hit(deck,hand):
    hand.add_card(deck.deal())
    
def hit_or_stand(deck,hand):
    global playing
    
    while True:
        x = input(f"You are at {player_hand.value}\nWould you like to Hit or Stand? Enter 'h' or 's' ")
        
        if x[0].lower() == 'h':
            hit(deck,hand)  

        elif x[0].lower() == 's':
            print("Player stands. Dealer is playing.")
            playing = False

        else:
            print("Sorry, please try again.")
            continue
        break

    
def show_some(player,dealer):
    print("\nDealer's Hand:")
    print(" <card hidden>")
    print('',dealer.cards[1])  
    print("\nPlayer's Hand:", *player.cards, sep='\n ')
    
def show_all(player,dealer):
    print("\nDealer's Hand:", *dealer.cards, sep='\n ')
    print("Dealer's Hand =",dealer.value)
    print("\nPlayer's Hand:", *player.cards, sep='\n ')
    print("Player's Hand =",player.value)
    
def player_busts(player,dealer,chips):
    print("Player busts!")
    chips.lose_bet()

def player_wins(player,dealer,chips):
    print("Player wins!")
    chips.win_bet()

def dealer_busts(player,dealer,chips):
    print("Dealer busts!")
    chips.win_bet()
    
def dealer_wins(player,dealer,chips):
    print("Dealer wins!")
    chips.lose_bet()
    
def push(player,dealer):
    print("Dealer and Player tie! It's a push.")
    

while True:
    print('Welcome to 7 and a half! Get as close to 7.5 as you can without going over!\n\
    Dealer hits until she reaches 7. Aces count as 1.')
    
   
    deck = Deck()
    deck.shuffle()
    
    player_hand = Hand()
    player_hand.add_card(deck.deal())
    player_hand.add_card(deck.deal())
    
    dealer_hand = Hand()
    dealer_hand.add_card(deck.deal())
    dealer_hand.add_card(deck.deal())
    
    
    player_chips = Chips()  
    
    
    take_bet(player_chips)
    
    
    show_some(player_hand,dealer_hand)
    
    while playing: 
        
    
        hit_or_stand(deck,player_hand)
        show_some(player_hand,dealer_hand)
        
        if player_hand.value > 7.5:
            player_busts(player_hand,dealer_hand,player_chips)
            break
    
    
    if player_hand.value <= 7.5:
        
        while dealer_hand.value < 4.5:
            hit(deck,dealer_hand)
            
    
        show_all(player_hand,dealer_hand)
        
    
        if dealer_hand.value > 7.5:
            dealer_busts(player_hand,dealer_hand,player_chips)

        elif dealer_hand.value > player_hand.value:
            dealer_wins(player_hand,dealer_hand,player_chips)

        elif dealer_hand.value < player_hand.value:
            player_wins(player_hand,dealer_hand,player_chips)

        else:
            push(player_hand,dealer_hand)

    
    print("\nPlayer's winnings stand at",player_chips.total)
    
    
    new_game = input("Would you like to play another hand? Enter 'y' or 'n' ")
    if new_game[0].lower()=='y':
        playing=True
        continue
    else:
        print("Thanks for playing!")
        break
# Out:
# Welcome to 7 and a half! Get as close to 7.5 as you can without going over!
#     Dealer hits until she reaches 7. Aces count as 1.
# How many chips would you like to bet?  2
# Dealer's Hand:
#  <card hidden>
#  Queen of Spades
#
# Player's Hand:
#  Four of Clubs
#  Ace of Clubs
# You are at 5
# Would you like to Hit or Stand? Enter 'h' or 's'  s
# Player stands. Dealer is playing.
#
# Dealer's Hand:
#  <card hidden>
#  Queen of Spades
#
# Player's Hand:
#  Four of Clubs
#  Ace of Clubs
#
# Dealer's Hand:
#  Queen of Clubs
#  Queen of Spades
#  Jack of Spades
#  Five of Spades
# Dealer's Hand = 6.5
#
# Player's Hand:
#  Four of Clubs
#  Ace of Clubs
# Player's Hand = 5
# Dealer wins!
#
# Player's winnings stand at 3
# Would you like to play another hand? Enter 'y' or 'n'  n
# Thanks for playing!
